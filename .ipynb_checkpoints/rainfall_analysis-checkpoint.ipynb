# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load data and preprocessing labels
fn = "whole_rain_1973-2022.csv"
df = pd.read_csv(fn)
df = df.dropna()
df['date'] = df.date.apply(lambda x: pd.Timestamp(x))
df['year'] = df.date.apply(lambda x: x.year)
df['month'] = df.date.apply(lambda x:x.month)
df['season'] = 4
df.loc[(df.month>=3)&(df.month<=5),'season'] = 1
df.loc[(df.month>=6)&(df.month<=8),'season'] = 2
df.loc[(df.month>=9)&(df.month<=11),'season'] = 3


gb = dict(list(df.groupby('year')))
c = "rain(mm)"
years = list(range(1973,2023,1))

# %%
# yearly analysis per group by month
for year in years:
    temp = gb[year].sort_values('date').reset_index()
    lines = temp.groupby('month').mean()[c]
    lines = temp[c].values
    # plt.cla()
    # plt.plot(lines,label = "%d"%year)
    # plt.ylim(0,90)
    # plt.xlim(0,370)
    # plt.legend()
    # plt.savefig("rainfall/r%d.png"%year)

# %%
# Aggregate Analysis
maxfall = pd.Series(dtype = float)
maxdate = pd.Series(dtype = float)
rainsum = pd.Series(dtype = float)
for year in years:
    temp = gb[year].sort_values('date').reset_index()
    maxfall.loc[year] = temp[c].max()
    rainsum.loc[year] = temp[c].sum()
    idx = temp[c].idxmax()
    maxdate.loc[year] = temp.loc[idx,'date'].month * 100 + temp.loc[idx,'date'].day

# %%
# monthly average and stdev
events = pd.DataFrame(columns=['s1','s2','mean','std'])
for year in years:
    temp = gb[year].sort_values('date').reset_index()
    mean = temp[c].mean()
    std=temp[c].std()
    s1 = (temp[c]>(mean+std)).sum()
    s2 = (temp[c]>(mean+std*2)).sum()
    
    events.loc[year] = [s1,s2,mean,std]

# %%
# seasonal analysis
res=pd.DataFrame(columns = ['spring_mean','summer_mean','fall_mean','winter_mean','spring_sum','summer_sum','fall_sum','winter_sum','spring_max','summer_max','fall_max','winter_max'])
for year in years:
    temp = gb[year].sort_values('date').reset_index()
    sgb = temp.groupby('season')
    mean = sgb[c].mean()
    summ = sgb[c].sum()
    maxx = sgb[c].max()
    res.loc[year] = list(mean.values)+list(summ.values)+list(maxx.values)

# %%
res[['spring_mean','summer_mean','fall_mean','winter_mean']].plot()
# Out:
# <AxesSubplot:>

# %%
res[['spring_sum','summer_sum','fall_sum','winter_sum']].plot()
# Out:
# <AxesSubplot:>

# %%
res[['spring_max','summer_max','fall_max','winter_max']].plot()
# Out:
# <AxesSubplot:>
